# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %%
shopee_data=pd.read_excel('Tai_nguyen_cung_cap/shopee_data.xlsx')
shopee_data.head()
# Out:
#    Unnamed: 0                                            Tên sp:  \
# 0           0                                 Sạc đa năng laptop
# 1           1  Lót chuột - Pad chuột máy tính (11 họa tiết kh...
# 2           2                    Chuột Dây Asus Sica Gaming P301
# 3           3    [PHÂN PHỐI] Bút thuyết trình chính hãng 1 đổi 1
# 4           4  Máy chiếu Led Salange M18-2020 1080P 15w đã sử...
#
#               label:                                           Danh Mục  \
# 0  May_tinh_&_Laptop                           Shopee-Máy tính & Laptop
# 1  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Bàn D...
# 2  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Chuột...
# 3  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...
# 4  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...
#
#    Kho hàng                              Gửi từ  sale_price  org_price  \
# 0       100               Quận Cầu Giấy, Hà Nội      115000     115000
# 1       694              Quận Hoàng Mai, Hà Nội       25000      25000
# 2         5       Quận Thủ Đức, TP. Hồ Chí Minh      380000     590000
# 3     49699     Quận Phú Nhuận, TP. Hồ Chí Minh      299000     450000
# 4       100  Thành Phố Thái Nguyên, Thái Nguyên     3590000    5500000
#
#    discount  star  ...                                            img_url  \
# 0      0.00   0.0  ...  "https://cf.shopee.vn/file/25c4ee019c051cb3829...
# 1      0.00   4.8  ...                                                NaN
# 2      0.36   0.0  ...  "https://cf.shopee.vn/file/46e5adc31cf7f23404c...
# 3      0.34   5.0  ...  "https://cf.shopee.vn/file/6f9fae7be7f3b6cca1e...
# 4      0.35   0.0  ...  "https://cf.shopee.vn/file/bd3906cfa7a6a224f7f...
#
#   selled  ĐáNh GiÁ  SẢN PhẨM  TỈ LỆ PhẢN HỒI  ThỜI Gian PhẢN HỒI  \
# 0      0        41       127            1.00       trong vài giờ
# 1    308       478       113            0.83      trong vài ngày
# 2      0        19       130            1.00       trong vài giờ
# 3    301        51         8            0.86      trong vài ngày
# 4      0        34        37            0.93      trong vài ngày
#
#          Tham Gia NgƯờI Theo DÕI Thương hiệu        Bảo Hành
# 0  33 tháng trước           1,5k         NaN             NaN
# 1  12 tháng trước           3,8k    no brand  Không Bảo Hành
# 2   3 tháng trước           4,4k        asus             NaN
# 3   2 tháng trước          10,5k    logitech         3 tháng
# 4  14 tháng trước           6,8k    no brand        10 tháng
#
# [5 rows x 21 columns]

# %%
shopee_data.tail()
# Out:
#      Unnamed: 0                                            Tên sp:  \
# 499         500  Bộ kích sóng wifi Mercury MW310re 300Mbps 3 râ...
# 500         501  Bộ Chia Mạng Switch 16 Cổng Linksys LGS116 Tốc...
# 501         502  Bộ Chia Mạng Switch 24 Cổng Linksys LGS124 Tốc...
# 502         503  Bộ Phát Wifi Mesh MU-MIMO Linksys MR8300 Chuản...
# 503         504  Bộ phát Wifi MU-MIMO Linksys EA8500 Max-Strea...
#
#                 label:                                           Danh Mục  \
# 499  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Kích...
# 500  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ chia...
# 501  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ chia...
# 502  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Phát...
# 503  May_tinh_&_Laptop  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Phát...
#
#      Kho hàng                          Gửi từ  sale_price  org_price  \
# 499       249          Quận Hoàng Mai, Hà Nội      169000     199000
# 500        10  Quận Bình Tân, TP. Hồ Chí Minh     2399000    2899000
# 501        10  Quận Bình Tân, TP. Hồ Chí Minh     3099000    3399000
# 502        10  Quận Bình Tân, TP. Hồ Chí Minh     3899000    5100000
# 503        10  Quận Bình Tân, TP. Hồ Chí Minh     6499000    7499000
#
#      discount  star  ...                                            img_url  \
# 499      0.15   4.7  ...                                                NaN
# 500      0.17   0.0  ...  "https://cf.shopee.vn/file/118c26e35d3d7545cf7...
# 501      0.09   0.0  ...  "https://cf.shopee.vn/file/79fce7931a0214952e5...
# 502      0.24   0.0  ...  "https://cf.shopee.vn/file/86f635933668b67d795...
# 503      0.13   0.0  ...  "https://cf.shopee.vn/file/900d5afcd0e56f1358a...
#
#     selled  ĐáNh GiÁ  SẢN PhẨM  TỈ LỆ PhẢN HỒI  ThỜI Gian PhẢN HỒI  \
# 499   4300      3200       130            0.96      trong vài ngày
# 500      0        10        68            0.79       trong vài giờ
# 501      0        10        68            0.79       trong vài giờ
# 502      0        10        68            0.79       trong vài giờ
# 503      0        10        68            0.79       trong vài giờ
#
#            Tham Gia NgƯờI Theo DÕI Thương hiệu  Bảo Hành
# 499  24 tháng trước            844     mercury  12 tháng
# 500     4 năm trước           3,3k     linksys  36 tháng
# 501     4 năm trước           3,3k     linksys  36 tháng
# 502     4 năm trước           3,3k     linksys  36 tháng
# 503     4 năm trước           3,3k     linksys  36 tháng
#
# [5 rows x 21 columns]

# %%
shopee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          504 non-null    int64
#  1   Tên sp:             504 non-null    object
#  2   label:              504 non-null    object
#  3   Danh Mục            504 non-null    object
#  4   Kho hàng            504 non-null    int64
#  5   Gửi từ              503 non-null    object
#  6   sale_price          504 non-null    int64
#  7   org_price           504 non-null    int64
#  8   discount            504 non-null    float64
#  9   star                504 non-null    float64
#  10  rating              504 non-null    object
#  11  img_url             464 non-null    object
#  12  selled              504 non-null    int64
#  13  ĐáNh GiÁ            504 non-null    int64
#  14  SẢN PhẨM            504 non-null    int64
#  15  TỈ LỆ PhẢN HỒI      504 non-null    float64
#  16  ThỜI Gian PhẢN HỒI  504 non-null    object
#  17  Tham Gia            504 non-null    object
#  18  NgƯờI Theo DÕI      504 non-null    object
#  19  Thương hiệu         447 non-null    object
#  20  Bảo Hành            382 non-null    object
# dtypes: float64(3), int64(7), object(11)
# memory usage: 82.8+ KB

# %%
shopee_data.describe()
# Out:
#        Unnamed: 0      Kho hàng    sale_price     org_price    discount  \
# count  504.000000    504.000000  5.040000e+02  5.040000e+02  504.000000
# mean   251.819444    833.158730  1.092297e+06  1.225891e+06    0.087579
# std    146.013715   6517.507065  1.996300e+06  2.201766e+06    0.133548
# min      0.000000      1.000000  6.400000e+03  6.400000e+03    0.000000
# 25%    125.750000     10.000000  9.650000e+04  1.100000e+05    0.000000
# 50%    251.500000     50.000000  2.550000e+05  2.775000e+05    0.000000
# 75%    378.250000    100.000000  8.990000e+05  1.051000e+06    0.152500
# max    504.000000  99067.000000  1.499000e+07  1.499000e+07    0.550000
#
#              star       selled       ĐáNh GiÁ     SẢN PhẨM  TỈ LỆ PhẢN HỒI
# count  504.000000   504.000000     504.000000   504.000000      504.000000
# mean     1.652381    96.722222    1371.533730   333.501984        0.939524
# std      2.312313   528.437355   17186.431638   448.062664        0.137247
# min      0.000000     0.000000       0.000000     1.000000        0.040000
# 25%      0.000000     0.000000      41.000000    79.000000        0.940000
# 50%      0.000000     0.000000     108.000000   216.000000        0.990000
# 75%      4.900000     4.000000     552.750000   308.250000        1.000000
# max      5.000000  6500.000000  383600.000000  2100.000000        1.000000

# %%
shopee_data = shopee_data.loc[:,~shopee_data.columns.str.startswith('Unnamed')]
print('So dong la: ', shopee_data.shape[0])
print('So cot la: ', shopee_data.shape[1])
# Out:
# So dong la:  504
# So cot la:  20

# %%
# 5 thương hiệu được liệt kê nhiều nhất trong datasets
shopee_data['Thương hiệu'].value_counts().head()
# Out:
# no brand            206
# hp                   28
# dell                 18
# coolman sunshine     13
# tp-link              13
# Name: Thương hiệu, dtype: int64

# %%
# 4. Drop các cột  'img_url', 'ThỜI Gian PhẢN HỒI', 'Tham Gia' (0.25 điểm)
shopee_data.drop(columns=['img_url', 'ThỜI Gian PhẢN HỒI', 'Tham Gia'], inplace=True)
shopee_data
# Out:
#                                                Tên sp:             label:  \
# 0                                   Sạc đa năng laptop  May_tinh_&_Laptop
# 1    Lót chuột - Pad chuột máy tính (11 họa tiết kh...  May_tinh_&_Laptop
# 2                      Chuột Dây Asus Sica Gaming P301  May_tinh_&_Laptop
# 3      [PHÂN PHỐI] Bút thuyết trình chính hãng 1 đổi 1  May_tinh_&_Laptop
# 4    Máy chiếu Led Salange M18-2020 1080P 15w đã sử...  May_tinh_&_Laptop
# ..                                                 ...                ...
# 499  Bộ kích sóng wifi Mercury MW310re 300Mbps 3 râ...  May_tinh_&_Laptop
# 500  Bộ Chia Mạng Switch 16 Cổng Linksys LGS116 Tốc...  May_tinh_&_Laptop
# 501  Bộ Chia Mạng Switch 24 Cổng Linksys LGS124 Tốc...  May_tinh_&_Laptop
# 502  Bộ Phát Wifi Mesh MU-MIMO Linksys MR8300 Chuản...  May_tinh_&_Laptop
# 503  Bộ phát Wifi MU-MIMO Linksys EA8500 Max-Strea...  May_tinh_&_Laptop
#
#                                               Danh Mục  Kho hàng  \
# 0                             Shopee-Máy tính & Laptop       100
# 1    Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Bàn D...       694
# 2    Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Chuột...         5
# 3    Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...     49699
# 4    Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...       100
# ..                                                 ...       ...
# 499  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Kích...       249
# 500  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ chia...        10
# 501  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ chia...        10
# 502  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Phát...        10
# 503  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Phát...        10
#
#                                  Gửi từ  sale_price  org_price  discount  \
# 0                 Quận Cầu Giấy, Hà Nội      115000     115000      0.00
# 1                Quận Hoàng Mai, Hà Nội       25000      25000      0.00
# 2         Quận Thủ Đức, TP. Hồ Chí Minh      380000     590000      0.36
# 3       Quận Phú Nhuận, TP. Hồ Chí Minh      299000     450000      0.34
# 4    Thành Phố Thái Nguyên, Thái Nguyên     3590000    5500000      0.35
# ..                                  ...         ...        ...       ...
# 499              Quận Hoàng Mai, Hà Nội      169000     199000      0.15
# 500      Quận Bình Tân, TP. Hồ Chí Minh     2399000    2899000      0.17
# 501      Quận Bình Tân, TP. Hồ Chí Minh     3099000    3399000      0.09
# 502      Quận Bình Tân, TP. Hồ Chí Minh     3899000    5100000      0.24
# 503      Quận Bình Tân, TP. Hồ Chí Minh     6499000    7499000      0.13
#
#      star rating  selled  ĐáNh GiÁ  SẢN PhẨM  TỈ LỆ PhẢN HỒI NgƯờI Theo DÕI  \
# 0     0.0      0       0        41       127            1.00           1,5k
# 1     4.8     61     308       478       113            0.83           3,8k
# 2     0.0      0       0        19       130            1.00           4,4k
# 3     5.0      1     301        51         8            0.86          10,5k
# 4     0.0      0       0        34        37            0.93           6,8k
# ..    ...    ...     ...       ...       ...             ...            ...
# 499   4.7   1,2k    4300      3200       130            0.96            844
# 500   0.0      0       0        10        68            0.79           3,3k
# 501   0.0      0       0        10        68            0.79           3,3k
# 502   0.0      0       0        10        68            0.79           3,3k
# 503   0.0      0       0        10        68            0.79           3,3k
#
#     Thương hiệu        Bảo Hành
# 0           NaN             NaN
# 1      no brand  Không Bảo Hành
# 2          asus             NaN
# 3      logitech         3 tháng
# 4      no brand        10 tháng
# ..          ...             ...
# 499     mercury        12 tháng
# 500     linksys        36 tháng
# 501     linksys        36 tháng
# 502     linksys        36 tháng
# 503     linksys        36 tháng
#
# [504 rows x 17 columns]

# %%
# 5. Cột 'NgƯờI Theo DÕI' giá trị có 4 chữ số sẽ được chuyển thành dạng chữ 1000 --> 1k, hãy đổi lại thành dạng số. 
# Nếu bị null, hãy drop bỏ dòng đó (0.5 điểm).

regex_pat = re.compile(r'[kKM]+$|,', flags=re.IGNORECASE)
shopee_data['NgƯờI Theo DÕI'] = shopee_data['NgƯờI Theo DÕI'].replace(regex_pat, '', regex=True).astype(float)*shopee_data['NgƯờI Theo DÕI'].str.extract(r'[\d\.]+([kM]+)', expand=False).fillna(1).replace(['k','M'], [10**3, 10**6]).astype(int)
shopee_data
# Out:
#                                                Tên sp:             label:  \
# 0                                   Sạc đa năng laptop  May_tinh_&_Laptop
# 1    Lót chuột - Pad chuột máy tính (11 họa tiết kh...  May_tinh_&_Laptop
# 2                      Chuột Dây Asus Sica Gaming P301  May_tinh_&_Laptop
# 3      [PHÂN PHỐI] Bút thuyết trình chính hãng 1 đổi 1  May_tinh_&_Laptop
# 4    Máy chiếu Led Salange M18-2020 1080P 15w đã sử...  May_tinh_&_Laptop
# ..                                                 ...                ...
# 499  Bộ kích sóng wifi Mercury MW310re 300Mbps 3 râ...  May_tinh_&_Laptop
# 500  Bộ Chia Mạng Switch 16 Cổng Linksys LGS116 Tốc...  May_tinh_&_Laptop
# 501  Bộ Chia Mạng Switch 24 Cổng Linksys LGS124 Tốc...  May_tinh_&_Laptop
# 502  Bộ Phát Wifi Mesh MU-MIMO Linksys MR8300 Chuản...  May_tinh_&_Laptop
# 503  Bộ phát Wifi MU-MIMO Linksys EA8500 Max-Strea...  May_tinh_&_Laptop
#
#                                               Danh Mục  Kho hàng  \
# 0                             Shopee-Máy tính & Laptop       100
# 1    Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Bàn D...       694
# 2    Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Chuột...         5
# 3    Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...     49699
# 4    Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...       100
# ..                                                 ...       ...
# 499  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Kích...       249
# 500  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ chia...        10
# 501  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ chia...        10
# 502  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Phát...        10
# 503  Shopee-Máy tính & Laptop-Thiết Bị Mạng-Bộ Phát...        10
#
#                                  Gửi từ  sale_price  org_price  discount  \
# 0                 Quận Cầu Giấy, Hà Nội      115000     115000      0.00
# 1                Quận Hoàng Mai, Hà Nội       25000      25000      0.00
# 2         Quận Thủ Đức, TP. Hồ Chí Minh      380000     590000      0.36
# 3       Quận Phú Nhuận, TP. Hồ Chí Minh      299000     450000      0.34
# 4    Thành Phố Thái Nguyên, Thái Nguyên     3590000    5500000      0.35
# ..                                  ...         ...        ...       ...
# 499              Quận Hoàng Mai, Hà Nội      169000     199000      0.15
# 500      Quận Bình Tân, TP. Hồ Chí Minh     2399000    2899000      0.17
# 501      Quận Bình Tân, TP. Hồ Chí Minh     3099000    3399000      0.09
# 502      Quận Bình Tân, TP. Hồ Chí Minh     3899000    5100000      0.24
# 503      Quận Bình Tân, TP. Hồ Chí Minh     6499000    7499000      0.13
#
#      star rating  selled  ĐáNh GiÁ  SẢN PhẨM  TỈ LỆ PhẢN HỒI  NgƯờI Theo DÕI  \
# 0     0.0      0       0        41       127            1.00         15000.0
# 1     4.8     61     308       478       113            0.83         38000.0
# 2     0.0      0       0        19       130            1.00         44000.0
# 3     5.0      1     301        51         8            0.86        105000.0
# 4     0.0      0       0        34        37            0.93         68000.0
# ..    ...    ...     ...       ...       ...             ...             ...
# 499   4.7   1,2k    4300      3200       130            0.96           844.0
# 500   0.0      0       0        10        68            0.79         33000.0
# 501   0.0      0       0        10        68            0.79         33000.0
# 502   0.0      0       0        10        68            0.79         33000.0
# 503   0.0      0       0        10        68            0.79         33000.0
#
#     Thương hiệu        Bảo Hành
# 0           NaN             NaN
# 1      no brand  Không Bảo Hành
# 2          asus             NaN
# 3      logitech         3 tháng
# 4      no brand        10 tháng
# ..          ...             ...
# 499     mercury        12 tháng
# 500     linksys        36 tháng
# 501     linksys        36 tháng
# 502     linksys        36 tháng
# 503     linksys        36 tháng
#
# [504 rows x 17 columns]

# %%
# 6.Vẽ lmplot giữa sale_price và org_price và nhận xét (0.75 điểm)
sns.lmplot(
    data=shopee_data,
    x='sale_price',
    y='org_price'
)
# Trong mối quan hệ tuyến tính giữa sale_price và org_price, 
# ta thấy rằng khi giá trị sản phẩm càng cao, 
# người bán hàng thường tăng khoảng chênh lệch giữa giá bán và giá bán sau khi giảm giá, 
# độ tin cậy dữ liệu càng giảm dần.

# %%
# 7.	Vẽ jointplot giữa cột SẢN PhẨM và NgƯờI Theo DÕI và nhận xét (0.75 điểm)
sns.jointplot(
    data=shopee_data,
    x='SẢN PhẨM',
    y='NgƯờI Theo DÕI'
)
# Biểu đồ tập trung về khu vực nhà cung cấp có ít sản phẩm và có ít người theo dõi. 
# Cũng có một số số liệu không đáng tin cậy khi nhà cung cấp có ít sản phẩm nhưng vẫn có rất nhiều người theo dõi.

# %%
# 8.	Kiểm tra xem 2 cột Kho hàng và SẢN PhẨM có hệ số tương quan là bao nhiêu (0.25 điểm)
shopee_data[['Kho hàng', 'SẢN PhẨM']].corr()
# Out:
#           Kho hàng  SẢN PhẨM
# Kho hàng  1.000000 -0.050297
# SẢN PhẨM -0.050297  1.000000

# %%
# Vẽ displot của discount và nhận xét biểu đồ (0.5 điểm)
sns.distplot(
    shopee_data.discount
)
# Hầu hết các cấp sản phẩm đều không có discount
# Out:
# /home/hunglv/Desktop/course-MachineLearning/venv/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='discount', ylabel='Density'>

# %%
# 10.	Tách phần tử cuối cùng sau dấu , của cột Gửi từ để tạo thành cột vị trí kho hàng (0.5 điểm)
shopee_data['Vị trí kho hàng']=shopee_data['Gửi từ'].str.rsplit(',').str[-1] 
shopee_data.head()
# Out:
#                                              Tên sp:             label:  \
# 0                                 Sạc đa năng laptop  May_tinh_&_Laptop
# 1  Lót chuột - Pad chuột máy tính (11 họa tiết kh...  May_tinh_&_Laptop
# 2                    Chuột Dây Asus Sica Gaming P301  May_tinh_&_Laptop
# 3    [PHÂN PHỐI] Bút thuyết trình chính hãng 1 đổi 1  May_tinh_&_Laptop
# 4  Máy chiếu Led Salange M18-2020 1080P 15w đã sử...  May_tinh_&_Laptop
#
#                                             Danh Mục  Kho hàng  \
# 0                           Shopee-Máy tính & Laptop       100
# 1  Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Bàn D...       694
# 2  Shopee-Máy tính & Laptop-Chuột, Bàn Phím-Chuột...         5
# 3  Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...     49699
# 4  Shopee-Máy tính & Laptop-Máy In, Máy Scan & Má...       100
#
#                                Gửi từ  sale_price  org_price  discount  star  \
# 0               Quận Cầu Giấy, Hà Nội      115000     115000      0.00   0.0
# 1              Quận Hoàng Mai, Hà Nội       25000      25000      0.00   4.8
# 2       Quận Thủ Đức, TP. Hồ Chí Minh      380000     590000      0.36   0.0
# 3     Quận Phú Nhuận, TP. Hồ Chí Minh      299000     450000      0.34   5.0
# 4  Thành Phố Thái Nguyên, Thái Nguyên     3590000    5500000      0.35   0.0
#
#   rating  selled  ĐáNh GiÁ  SẢN PhẨM  TỈ LỆ PhẢN HỒI  NgƯờI Theo DÕI  \
# 0      0       0        41       127            1.00         15000.0
# 1     61     308       478       113            0.83         38000.0
# 2      0       0        19       130            1.00         44000.0
# 3      1     301        51         8            0.86        105000.0
# 4      0       0        34        37            0.93         68000.0
#
#   Thương hiệu        Bảo Hành   Vị trí kho hàng
# 0         NaN             NaN            Hà Nội
# 1    no brand  Không Bảo Hành            Hà Nội
# 2        asus             NaN   TP. Hồ Chí Minh
# 3    logitech         3 tháng   TP. Hồ Chí Minh
# 4    no brand        10 tháng       Thái Nguyên

# %%
# 11.	Vẽ pie chart cột 'Vị trí kho hàng' với 5 vị trí nhiều nhất và nhận xét biểu đồ (0.5 điểm)
address=shopee_data['Vị trí kho hàng'].value_counts().head()
address.plot.pie(autopct='%.2f%%')
# Có hơn 54% sản phẩm được tập kết tại kho hàng Hà Nội, 
# kho hàng lớn thứ hai ở TP. Hồ Chí Minh.
# Out:
# <AxesSubplot:ylabel='Vị trí kho hàng'>

# %%
# 12.	Vẽ boxplot cột sale_price bằng matplotlib, nhận xét (0.5 điểm)
plt.boxplot(data=shopee_data,x='sale_price')
# Giá trị các sản phẩm không đồng đều nhau, sự chênh lệch giá giữa các sản phẩm là rất lớn.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f90f5331a90>,
#   <matplotlib.lines.Line2D at 0x7f90f5331df0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f90f52c0190>,
#   <matplotlib.lines.Line2D at 0x7f90f52c04f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f90f5331730>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f90f52c0850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f90f52c0bb0>],
#  'means': []}

# %%
# 13.	Loại bỏ outlier ở cột sale_price sử dụng công thức IQR để loại bỏ và in ra số dòng sau khi loại bỏ (0.5 điểm)
sale_price=shopee_data['sale_price']
Q1 = np.percentile(sale_price, 25, interpolation='midpoint')
Q3 = np.percentile(sale_price, 75, interpolation='midpoint') 
IQR = Q3 - Q1
Q4 = Q3 + 1.5 * IQR
print('số dòng còn lại sau khi loại bỏ outlier: ', len(shopee_data[shopee_data['sale_price'] <= Q4]))
# Out:
# số dòng còn lại sau khi loại bỏ outlier:  421

# %%
# 14.	Groupby Vị trí kho hàng, Thương hiệu rồi tính mean cột Kho hàng (0.25 điểm) 
shopee_data[['Vị trí kho hàng', 'Thương hiệu', 'Kho hàng']].groupby(['Vị trí kho hàng', 'Thương hiệu']).mean()
# Out:
#                                 Kho hàng
# Vị trí kho hàng Thương hiệu
#  An Giang       intel™       1112.000000
#  Bình Dương     asus            2.800000
#                 dell           11.333333
#                 hp             12.000000
#                 lenovo          8.500000
# ...                                  ...
#  Vĩnh Long      no brand       55.000000
#                 toshiba        23.666667
#                 tp-link        17.000000
#  Đắk Lắk        lb-link        95.000000
#  Đồng Nai       no brand      500.000000
#
# [116 rows x 1 columns]

# %%
# 15.	Vẽ catplot cho cột sale_price, kind=box, col=Thương hiệu, col_order='hp','lenovo','acer','mercury' và nhận xét biểu đồ (0.5 điểm)
sns.catplot(
    data=shopee_data,
    y='sale_price',
    kind='box',
    col='Thương hiệu',
    col_order=['hp','lenovo','acer','mercury']
)
# Các thương hiệu có uy tín như HP, Lenovo, Acer có giá sản phẩm đã niêm yết nên hầu như các store có giá đồng đều nhau, 
# riêng đối với sản phẩm Mercury thì xuất hiện một số giá trị Outlier

# %%
sns.catplot(
    data=shopee_data,
    y='sale_price',
    kind='violin',
    col='Thương hiệu',
    col_order=['hp','lenovo','acer','mercury']
)
