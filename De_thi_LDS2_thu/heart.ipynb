# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
heart = pd.read_csv('tai_nguyen_cung_cap/heart.csv')
heart.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    1   3     145.0  233.0    1        0      150      0      2.3
# 1   37    1   2     130.0  250.0    0        1      187      0      3.5
# 2   41    0   1     130.0  204.0    0        0      172      0      1.4
# 3   56    1   1     120.0  236.0    0        1      178      0      0.8
# 4   57    0   0     120.0  354.0    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
heart.tail()
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0     140.0  241.0    0        1      123      1      0.2
# 299   45    1   3     110.0    NaN    0        1      132      0      1.2
# 300   68    1   0     144.0  193.0    1        1      141      0      3.4
# 301   57    1   0     130.0  131.0    0        1      115      1      1.2
# 302   57    0   1     130.0  236.0    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  286 non-null    float64
#  4   chol      284 non-null    float64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  286.000000  284.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.374126  247.577465    0.148515
# std      9.082101    0.466011    1.032052   17.597545   52.024162    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.750000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  242.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  275.250000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart.fillna(0)
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3     145.0  233.0    1        0      150      0      2.3
# 1     37    1   2     130.0  250.0    0        1      187      0      3.5
# 2     41    0   1     130.0  204.0    0        0      172      0      1.4
# 3     56    1   1     120.0  236.0    0        1      178      0      0.8
# 4     57    0   0     120.0  354.0    0        1      163      1      0.6
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 298   57    0   0     140.0  241.0    0        1      123      1      0.2
# 299   45    1   3     110.0    0.0    0        1      132      0      1.2
# 300   68    1   0     144.0  193.0    1        1      141      0      3.4
# 301   57    1   0     130.0  131.0    0        1      115      1      1.2
# 302   57    0   1     130.0  236.0    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
heart.groupby('cp').size().reset_index(name='counts')
# Out:
#    cp  counts
# 0   0     143
# 1   1      50
# 2   2      87
# 3   3      23

# %%
heart.columns[heart.isna().any()].tolist()
# Out:
# ['trestbps', 'chol']

# %%
heart.drop(columns=['ca', 'thal'], inplace=True)
heart
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3     145.0  233.0    1        0      150      0      2.3
# 1     37    1   2     130.0  250.0    0        1      187      0      3.5
# 2     41    0   1     130.0  204.0    0        0      172      0      1.4
# 3     56    1   1     120.0  236.0    0        1      178      0      0.8
# 4     57    0   0     120.0  354.0    0        1      163      1      0.6
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 298   57    0   0     140.0  241.0    0        1      123      1      0.2
# 299   45    1   3     110.0    NaN    0        1      132      0      1.2
# 300   68    1   0     144.0  193.0    1        1      141      0      3.4
# 301   57    1   0     130.0  131.0    0        1      115      1      1.2
# 302   57    0   1     130.0  236.0    0        0      174      0      0.0
#
#      slope  target
# 0        0       1
# 1        0       1
# ...

# %%
# heart.groupby('sex').count()
heart.boxplot(
    column=['thalach'],
    by='sex',
    figsize=(10, 8),
    grid=False
)
# Out:
# <AxesSubplot:title={'center':'thalach'}, xlabel='sex'>

# %%
heart.chol = heart.chol.interpolate()
heart.chol
# Out:
# 0      233.0
# 1      250.0
# 2      204.0
# 3      236.0
# 4      354.0
#        ...
# 298    241.0
# 299    217.0
# 300    193.0
# 301    131.0
# 302    236.0
# Name: chol, Length: 303, dtype: float64

# %%
heart.trestbps.fillna(heart.trestbps.mean())
# Out:
# 0      145.0
# 1      130.0
# 2      130.0
# 3      120.0
# 4      120.0
#        ...
# 298    140.0
# 299    110.0
# 300    144.0
# 301    130.0
# 302    130.0
# Name: trestbps, Length: 303, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.scatter('age', 'chol', data=heart)
plt.xlabel('age')
plt.ylabel('chol')
# Out:
# Text(0, 0.5, 'chol')

# %%
# 9. Tìm giá trung bình (mean) của trestbps giữa slope và restecg trong tập dataset. Sử dụng group by của slope và restecg để tính (0.5 điểm).
heart[['slope', 'restecg', 'trestbps']].groupby(['slope', 'restecg']).mean()

# heart.groupby(['slope', 'restecg']).mean()
# Out:
#                  trestbps
# slope restecg
# 0     0        148.333333
#       1        132.142857
#       2        114.000000
# 1     0        132.408451
#       1        129.543860
#       2        149.333333
# 2     0        131.870370
#       1        128.395062

# %%
figure, axes = plt.subplots(1, 2)
sns.regplot(
    data=heart,
    x='age',
    y='thalach',
    ax=axes[0]
)
sns.regplot(
    data=heart,
    x='age',
    y='trestbps',
    color='y',
    ax=axes[1]
)

# Tuổi càng cao thì tỉ lệ mắc thalach càng giảm,
# Tuổi càng cao thì tỉ lệ mắc trestbps càng tăng
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
d = heart.groupby('age').size().reset_index(name='count').sort_values('count', ascending=False).head()
d.plot.bar(
    'age',
    grid=False,
    legend=False
)
plt.xlabel('Tuổi')
plt.ylabel('Số lượt khảo sát')
plt.title('Số lượng tuổi được khảo sát nhiều nhất ')
# Out:
# Text(0.5, 1.0, 'Số lượng tuổi được khảo sát nhiều nhất ')

# %%
df_gender = heart.groupby('sex').size().reset_index(name='count')
print(df_gender)
df_gender['count'].plot.pie(autopct='%.2f%%')
plt.legend(['Female', 'Male'])
plt.title('Tỉ lệ Nam/Nữ')
# Out:
#    sex  count
# 0    0     96
# 1    1    207
# Text(0.5, 1.0, 'Tỉ lệ Nam/Nữ')

# %%
heart['oldpeak'].plot.box()
# Out:
# <AxesSubplot:>

# %%
oldpeak = heart['oldpeak']
median = oldpeak.median()
Q1 = np.percentile(oldpeak, 25, interpolation='midpoint') 
Q3 = np.percentile(oldpeak, 75, interpolation='midpoint') 
IQR = Q3 - Q1

# %%
Q4 = Q3 + 1.5 * (Q3 - Q1)
median = heart['oldpeak'].median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-633a63655e0b> in <module>
# ----> 1 Q4 = Q3 + 1.5 * (Q3 - Q1)
#       2 median = heart['oldpeak'].median()
#
# NameError: name 'Q3' is not defined
